# %%
import os
import glob
import pandas as pd

# %%
# load error dataframe
df = pd.read_csv('../all_error_type_results.csv')

# type of prompt_index
df['prompt_index'] = df['prompt_index'].astype(str)

# create column combining model, prompt_type, prompt_index, split
df['model_prompt_type_prompt_index_split'] = df['model'] + '_' + df['prompt_type'] + '_' + df['prompt_index'] + '_' + df['split']

# %%
# load best dev results
dev_df = pd.read_csv(os.path.join('..', 'best_dev_set_results.csv'))
# drop GLEU and F0.5 columns
dev_df = dev_df.drop(columns=['GLEU', 'F0.5'])

# split prompt_type_index into prompt_type and prompt_index
dev_df['prompt_type'] = dev_df['prompt_type_index'].apply(lambda x: x.split('_')[0])
dev_df['prompt_index'] = dev_df['prompt_type_index'].apply(lambda x: x.split('_')[1])

# drop prompt_type_index column
dev_df = dev_df.drop(columns=['prompt_type_index'])

# cast prompt_indx to str
dev_df['prompt_index'] = dev_df['prompt_index'].astype(str)

# create column combining model, prompt_type, prompt_index, split
dev_df['model_prompt_type_prompt_index_split'] = dev_df['model'] + '_' + dev_df['prompt_type'] + '_' + dev_df['prompt_index'] + '_' + dev_df['split']

# %%
def check_unique(df):
    dfcopy = df.copy()
    # select columns: model, prompt_type, prompt_index, split
    dfcopy = dfcopy[['model', 'prompt_type', 'prompt_index', 'split']]
    # drop duplicates
    dfcopy = dfcopy.drop_duplicates()

    return dfcopy.shape

# %%
check_unique(dev_df)
# Out:
# (30, 4)

# %%
dev_df.head()
# Out:
#                             model      split   prompt_type prompt_index  \
# 0                      gpt-4-0613  jfleg-dev        0-shot            8
# 1       stabilityai/StableBeluga2  jfleg-dev        0-shot           10
# 2  meta-llama/Llama-2-70b-chat-hf  jfleg-dev        0-shot            6
# 3      Writer/InstructPalmyra-20b  jfleg-dev        0-shot            7
# 4        facebook/opt-iml-max-30b  jfleg-dev  2-shot-Coyne            1
#
#                 model_prompt_type_prompt_index_split
# 0                      gpt-4-0613_0-shot_8_jfleg-dev
# 1      stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 2  meta-llama/Llama-2-70b-chat-hf_0-shot_6_jfleg-dev
# 3      Writer/InstructPalmyra-20b_0-shot_7_jfleg-dev
# 4  facebook/opt-iml-max-30b_2-shot-Coyne_1_jfleg-dev

# %%
df.head()
# Out:
#                    model prompt_type prompt_index    split Category  TP  FP  \
# 0  bigscience/bloomz-7b1      1-shot            1  fce-dev    M:ADJ   0   0
# 1  bigscience/bloomz-7b1      1-shot            1  fce-dev    M:ADV   1   4
# 2  bigscience/bloomz-7b1      1-shot            1  fce-dev   M:CONJ   0   0
# 3  bigscience/bloomz-7b1      1-shot            1  fce-dev  M:CONTR   0   0
# 4  bigscience/bloomz-7b1      1-shot            1  fce-dev    M:DET  16  14
#
#     FN       P       R    F0.5    model_prompt_type_prompt_index_split
# 0   10  1.0000  0.0000  0.0000  bigscience/bloomz-7b1_1-shot_1_fce-dev
# 1   26  0.2000  0.0370  0.1064  bigscience/bloomz-7b1_1-shot_1_fce-dev
# 2   16  1.0000  0.0000  0.0000  bigscience/bloomz-7b1_1-shot_1_fce-dev
# 3    1  1.0000  0.0000  0.0000  bigscience/bloomz-7b1_1-shot_1_fce-dev
# 4  198  0.5333  0.0748  0.2395  bigscience/bloomz-7b1_1-shot_1_fce-dev

# %%
# filter df to model=='stabilityai/StableBeluga2', prompt_type='0-shot', split='dev'
dev_df[(dev_df['model']=='stabilityai/StableBeluga2') & (dev_df['prompt_type']=='0-shot') & (dev_df['split']=='jfleg-dev') & (dev_df['prompt_index']=='10')]
# Out:
#                        model      split prompt_type prompt_index  \
# 1  stabilityai/StableBeluga2  jfleg-dev      0-shot           10
#
#             model_prompt_type_prompt_index_split
# 1  stabilityai/StableBeluga2_0-shot_10_jfleg-dev

# %%
# check before merge
check_unique(df)
# Out:
# (561, 4)

# %%
# use dev_def to select rows from df, using model_prompt_type_prompt_index_split as the key
dfmerge = df.merge(dev_df, how='inner', on=['model', 'prompt_type', 'prompt_index', 'split', 'model_prompt_type_prompt_index_split'])

# %%
dfmerge
# Out:
#                           model prompt_type prompt_index    split  \
# 0         bigscience/bloomz-7b1      3-shot            1  fce-dev
# 1         bigscience/bloomz-7b1      3-shot            1  fce-dev
# 2         bigscience/bloomz-7b1      3-shot            1  fce-dev
# 3         bigscience/bloomz-7b1      3-shot            1  fce-dev
# 4         bigscience/bloomz-7b1      3-shot            1  fce-dev
# ...                         ...         ...          ...      ...
# 1604  stabilityai/StableBeluga2      0-shot            7  fce-dev
# 1605  stabilityai/StableBeluga2      0-shot            7  fce-dev
# 1606  stabilityai/StableBeluga2      0-shot            7  fce-dev
# 1607  stabilityai/StableBeluga2      0-shot            7  fce-dev
# 1608  stabilityai/StableBeluga2      0-shot            7  fce-dev
#
#           Category  TP  FP   FN       P       R    F0.5  \
# 0            M:ADJ   0   0   10  1.0000  0.0000  0.0000
# 1            M:ADV   2   2   25  0.5000  0.0741  0.2326
# 2           M:CONJ   0   3   16  0.0000  0.0000  0.0000
# 3          M:CONTR   0   1    1  0.0000  0.0000  0.0000
# 4            M:DET  38  21  176  0.6441  0.1776  0.4222
# ...            ...  ..  ..  ...     ...     ...     ...
# 1604        U:PRON   8  25   10  0.2424  0.4444  0.2667
# 1605       U:PUNCT  18  50   27  0.2647  0.4000  0.2839
# 1606        U:VERB   7  12   17  0.3684  0.2917  0.3500
# 1607   U:VERB:FORM   1   4    1  0.2000  0.5000  0.2273
# 1608  U:VERB:TENSE  11  20   11  0.3548  0.5000  0.3767
#
#             model_prompt_type_prompt_index_split
# 0         bigscience/bloomz-7b1_3-shot_1_fce-dev
# 1         bigscience/bloomz-7b1_3-shot_1_fce-dev
# 2         bigscience/bloomz-7b1_3-shot_1_fce-dev
# 3         bigscience/bloomz-7b1_3-shot_1_fce-dev
# 4         bigscience/bloomz-7b1_3-shot_1_fce-dev
# ...                                          ...
# 1604  stabilityai/StableBeluga2_0-shot_7_fce-dev
# 1605  stabilityai/StableBeluga2_0-shot_7_fce-dev
# 1606  stabilityai/StableBeluga2_0-shot_7_fce-dev
# 1607  stabilityai/StableBeluga2_0-shot_7_fce-dev
# 1608  stabilityai/StableBeluga2_0-shot_7_fce-dev
#
# [1609 rows x 12 columns]

# %%
# filter df to model=='stabilityai/StableBeluga2', prompt_type='0-shot', split='dev'
dfmerge[(dfmerge['model']=='stabilityai/StableBeluga2') & (dfmerge['prompt_type']=='0-shot') & (dfmerge['split']=='jfleg-dev') & (dfmerge['prompt_index']=='10')]
# Out:
#                           model prompt_type prompt_index      split  \
# 1232  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1233  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1234  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1235  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1236  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1237  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1238  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1239  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1240  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1241  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1242  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1243  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1244  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1245  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1246  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1247  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1248  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1249  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1250  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1251  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1252  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1253  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1254  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1255  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1256  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1257  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1258  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1259  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1260  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1261  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1262  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1263  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1264  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1265  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1266  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1267  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1268  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1269  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1270  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1271  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1272  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1273  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1274  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1275  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1276  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1277  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1278  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1279  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1280  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1281  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1282  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1283  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
# 1284  stabilityai/StableBeluga2      0-shot           10  jfleg-dev
#
#           Category   TP   FP   FN       P       R    F0.5  \
# 1232         M:ADJ    0    5    5  0.0000  0.0000  0.0000
# 1233         M:ADV    3    7   13  0.3000  0.1875  0.2679
# 1234        M:CONJ    4    3   13  0.5714  0.2353  0.4444
# 1235       M:CONTR    1    0    0  1.0000  1.0000  1.0000
# 1236         M:DET   93   27   31  0.7750  0.7500  0.7699
# 1237        M:NOUN    9   17    6  0.3462  0.6000  0.3782
# 1238   M:NOUN:POSS    4    0    0  1.0000  1.0000  1.0000
# 1239       M:OTHER   13   36   53  0.2653  0.1970  0.2481
# 1240        M:PART    0    1    0  0.0000  1.0000  0.0000
# 1241        M:PREP   27   13   17  0.6750  0.6136  0.6618
# 1242        M:PRON    7    5    3  0.5833  0.7000  0.6034
# 1243       M:PUNCT  209  120   55  0.6353  0.7917  0.6614
# 1244        M:VERB   11    9   12  0.5500  0.4783  0.5340
# 1245   M:VERB:FORM    4    0    1  1.0000  0.8000  0.9524
# 1246  M:VERB:TENSE    6    4    7  0.6000  0.4615  0.5660
# 1247         R:ADJ    4   18    8  0.1818  0.3333  0.2000
# 1248    R:ADJ:FORM    3    0    3  1.0000  0.5000  0.8333
# 1249         R:ADV    4   10    8  0.2857  0.3333  0.2941
# 1250        R:CONJ    0    1    2  0.0000  0.0000  0.0000
# 1251       R:CONTR    0    7    4  0.0000  0.0000  0.0000
# 1252         R:DET   36   24   21  0.6000  0.6316  0.6061
# 1253       R:MORPH   36   14   18  0.7200  0.6667  0.7087
# 1254        R:NOUN   24   28   26  0.4615  0.4800  0.4651
# 1255   R:NOUN:INFL    8    0    1  1.0000  0.8889  0.9756
# 1256    R:NOUN:NUM   86   31   32  0.7350  0.7288  0.7338
# 1257   R:NOUN:POSS    4    4    2  0.5000  0.6667  0.5263
# 1258        R:ORTH  141   34   17  0.8057  0.8924  0.8217
# 1259       R:OTHER  105  182  225  0.3659  0.3182  0.3552
# 1260        R:PART    4    3    2  0.5714  0.6667  0.5882
# 1261        R:PREP   44   37   35  0.5432  0.5570  0.5459
# 1262        R:PRON   11   23    7  0.3235  0.6111  0.3571
# 1263       R:PUNCT    9   22   14  0.2903  0.3913  0.3061
# 1264       R:SPELL  297   52   38  0.8510  0.8866  0.8579
# 1265        R:VERB   27   45   48  0.3750  0.3600  0.3719
# 1266   R:VERB:FORM   30   26   20  0.5357  0.6000  0.5474
# 1267   R:VERB:INFL    4    2    0  0.6667  1.0000  0.7143
# 1268    R:VERB:SVA   57   14   11  0.8028  0.8382  0.8097
# 1269  R:VERB:TENSE   37   28   31  0.5692  0.5441  0.5640
# 1270          R:WO   17    6   12  0.7391  0.5862  0.7025
# 1271         U:ADJ    3    1    7  0.7500  0.3000  0.5769
# 1272         U:ADV    4    8   15  0.3333  0.2105  0.2985
# 1273        U:CONJ    2    4    5  0.3333  0.2857  0.3226
# 1274         U:DET   43   21   32  0.6719  0.5733  0.6495
# 1275        U:NOUN    6    7    9  0.4615  0.4000  0.4478
# 1276   U:NOUN:POSS    1    0    2  1.0000  0.3333  0.7143
# 1277       U:OTHER   11   20   31  0.3548  0.2619  0.3313
# 1278        U:PART    1    1    1  0.5000  0.5000  0.5000
# 1279        U:PREP   20    7   19  0.7407  0.5128  0.6803
# 1280        U:PRON    3    4    8  0.4286  0.2727  0.3846
# 1281       U:PUNCT   11    9   22  0.5500  0.3333  0.4867
# 1282        U:VERB   15    6    7  0.7143  0.6818  0.7075
# 1283   U:VERB:FORM    4    3    2  0.5714  0.6667  0.5882
# 1284  U:VERB:TENSE    7    4    3  0.6364  0.7000  0.6481
#
#                model_prompt_type_prompt_index_split
# 1232  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1233  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1234  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1235  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1236  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1237  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1238  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1239  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1240  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1241  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1242  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1243  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1244  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1245  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1246  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1247  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1248  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1249  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1250  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1251  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1252  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1253  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1254  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1255  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1256  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1257  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1258  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1259  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1260  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1261  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1262  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1263  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1264  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1265  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1266  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1267  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1268  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1269  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1270  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1271  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1272  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1273  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1274  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1275  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1276  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1277  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1278  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1279  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1280  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1281  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1282  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1283  stabilityai/StableBeluga2_0-shot_10_jfleg-dev
# 1284  stabilityai/StableBeluga2_0-shot_10_jfleg-dev

# %%
check_unique(dfmerge)
# Out:
# (30, 4)

# %%
dev_df.shape, dfmerge.shape
# Out:
# ((30, 5), (1609, 12))

# %%
# find rows in df that are NOT in dfmerge
dev_df[~dev_df['model_prompt_type_prompt_index_split'].isin(dfmerge['model_prompt_type_prompt_index_split'])]
# Out:
# Empty DataFrame
# Columns: [model, split, prompt_type, prompt_index, model_prompt_type_prompt_index_split]
# Index: []

# %%
# save dfmerge
dfmerge.to_csv('../best_dev_set_error_type_results.csv', index=False)
